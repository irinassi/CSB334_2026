# %% [markdown]
# # **Tutorial Goals**
#
# This is a beginner-friendly introduction to data manipulation and analysis in Python. Each tutorial will follow a ***code-along*** format, where students are expected to bring a computer and actively code alongside the TAs during the session.
#
# To reinforce the skills learned in class and help you prepare for your final coding project, we will introduce mini-assignments throughout the course. These are designed to help you practice and apply the concepts covered in each tutorial.
#
# The overall goal of this course is to introduce you to what data analysis looks like in graduate-level research, and to hopefully ***spark*** your interest in coding!
#
# ![ChatGPT%20Image%20Aug%2027,%202026,%2012_38_10%20PM.png](attachment:ChatGPT%20Image%20Aug%2027,%202026,%2012_38_10%20PM.png)

# %% [markdown]
# ## **Best Coding Habits to Save Your Future Self:**
#
# 1) **Annotate your code!** I guarantee you—whether you're analyzing fiber photometry, EEG or optogenetics data —you would not remember what your code is doing a week or even a day later. Use **#** to add comments that explain each step clearly.
#
#
# ```
# # this step calculates z-score formula to normalize fiber photometry signal
# ```
#
# 2) **Name your variables appropriately!** variable1 and someconstant might technically work, but they won’t help you (or anyone else) understand what’s going on in your code. Descriptive names make your code easier to read, debug, and share—especially in collaborative neuroscience projects.
#
# ```
# #bad example
# variable1 = 4
# thing = 2
# some_text = "sleep"
#
# #good example
# laser_power = 20
# stimulusOnsetTime = 1
#
# ```
# 3) **Divide code into smaller functions!** If you find yourself copying and pasting code to analyze multiple brain regions or trials, that’s a sign you need a function. Small functions help keep your workflow organized and make debugging much easier.
#
#
#
# ```
# def compute_delta_power(signal, sampling_rate):
#     # Returns power in delta band (0.5–4 Hz)
# ```

# %% [markdown]
# ## **Let's try to do some coding!**

# %% [markdown]
# # **Variables**
#
# In Python (and most programming languages), variables are used to store information that your code can **use, update, or refer to later.**
#
# How Do You Create a Variable?
# You assign a value using the **=** sign.

# %%
# REM Sleep EEG power
EEGpower = .. #integer (number)
# name of an experimental mouse
mouseID = ".." #string (text)
# condition of an exerimnental mouse
is_awake = .. #boolean variable (True or False)

# %% [markdown]
# You can check a type of your variable like this:

# %%
EEGpower = 0.5
type(..)

# %% [markdown]
# When you start performing more complex calculations, you'll often want to see the output of your code to check if it’s working as expected. You might notice that just assigning a value to a variable doesn’t display anything by itself.
#
# For example: 🐭

# %%
# number of mice in each experimental group
control_group = 5
experimental_group = 6

# %%
# number of mice in each experimental group
control_group = 5
experimental_group = 6

print("Number of mice in the control group: ", ..)
print("Number of mice in the experimental group: ", ..)

# %% [markdown]
# ## What happens if the variable is not defined?

# %%
print(n)

# %% [markdown]
# One of the most common errors you will encounter is a **NameError**.
#
# In Python, this usually means that you are trying to use a variable before assigning a value to it.

# %%
print(Control_group)

# %% [markdown]
# A **NameError** can also occur if you define a variable using lowercase letters but later refer to it using uppercase letters.
#
# ## **Remember: Python is case-sensitive!**

# %% [markdown]
# # **Simple Operations**
#
# Once we have some variables, we can perform simple operations with them, such as:
#
# 1.   Addition
# 2.   Substraction
# 3.   Multiplication
# 4.   Division

# %%
total_number_of_mice = ..
print(total_number_of_mice)

# %% [markdown]
# # **🐭 Comprehension Example**
#
# You ran a behavioral experiment with a mouse where it completed 15 trials in total. During the session, the mouse missed 4 trials (did not respond).
#
# **Q**: How many trials did the mouse successfully complete? Write the Python code to calculate the answer. Use annotated variables in your answer.

# %%
#type your answer here

# %% [markdown]
# # **Functions**
#
# Fortunately for us, Python includes built-in blocks of code called ***functions*** that can perform specific tasks—like calculating the mean or standard deviation. These functions save us time by doing common operations for us, without needing to write all the steps from scratch.
#
# For example:
# *   print() – displays output
# *   type() – tells you what kind of data you’re working with
#
# List of useful functions can be found here: https://www.w3schools.com/python/python_ref_functions.asp

# %% [markdown]
# ## **Libraries**
#
# However, some functions are not available right away-they are part of ***external libraries*** that need to be imported before you can use them.
#
# For example, functions to calculate the mean or standard deviation are in a popular library called ***numpy***. Before using them, you need to import the library like this:

# %%
import numpy as np

# %% [markdown]
# Keep in mind that to use functions from a library, you need to include the library name (or its **alias**) when calling the function—this tells Python where to find it.

# %% [markdown]
# # **Example: Finding Standard Deviation of REM Sleep Amounts Across 5 Days**

# %%
# REM Sleep Amounts in minutes Across 5 days

day1REMs = 2
day2REMs = 6
day3REMs = 4
day4REMs = 3
day5REMs = 0

std_REMs = np.""([day1REMs, day2REMs, day3REMs, day4REMs, day5REMs])
print(std_REMs)

# %% [markdown]
# You may have noticed that we used square brackets **[]** to pass multiple values into a function like np.std(). These brackets are used to create a list in Python, which is a collection of values stored together—like a container. Lists are especially helpful when you want **to store data points that belong to the same category or identity**, such as REM sleep amounts across different days, multiple trials, or different animals.
#
# **For example:**

# %%
remSleepAmounts = [2, 6, 4, 3, 0]
print(..)

# %% [markdown]
# You can do many of the same operations on lists as you can on regular variables!

# %% [markdown]
# # **🐭 Creating your Own Functions**
#
# You can even create your own functions that are not already available in Python or its libraries.
#
# You are a trainee in a sleep lab. You recorded the total sleep duration (in minutes) for control mice that have normal sleep and mice with insomnia.
#
# Compare the sleep amounts using numpy to calculate the average sleep amount and percentage difference between groups:

# %%
import numpy as np

ctrl_mice = [60, 126, 50, 300, 421]
insomniac_mice = [10, 1, 20, 30, 42]

# %%
#defining variables
ctrl_mice = [60, 126, 50, 300, 421]
insomniac_mice = [10, 1, 20, 30, 42]

def sleep_amounts_calc_percent_diff(.., ..): #definining a function
  avg_control_mice = np...(ctrl_mice) #calculating average for control and experimental mice
  avg_exp_mice = np...(insomniac_mice)
  percent_diff_between_groups = ((avg_exp_mice - avg_control_mice)/avg_control_mice)*100 #calculating percent difference between two groups
  return percent_diff_between_groups #returning an output

print(percent_diff_between_groups)

# %% [markdown]
# Notice that this operation gave you an error. That is because **percent_diff_between_groups** is a variable that exists **inside** the function. It’s not available outside the function unless you call the function and store or print the returned value.
#
# In order to access the output of a function, you must call the function by using its name followed by parentheses:

# %%
#defining variables
ctrl_mice = [60, 126, 50, 300, 421]
insomniac_mice = [10, 1, 20, 30, 42]

def sleep_amounts_calc_percent_diff(ctrl_mice, insomniac_mice): #definining a function
  avg_control_mice = np.mean(ctrl_mice) #calculating average for control and experimental mice
  avg_exp_mice = np.mean(insomniac_mice)
  percent_diff_between_groups = ((avg_exp_mice - avg_control_mice)/avg_control_mice)*100 #calculating percent difference between two groups
  return percent_diff_between_groups #returning an output

sleep_amounts_calc_percent_diff(ctrl_mice, insomniac_mice) #calling this function
print(sleep_amounts_calc_percent_diff(ctrl_mice, insomniac_mice))

# %% [markdown]
# ## **Indentation in Python**
#
# You might have noticed that the second line is moved slightly to the right. Why is that?
#
# This spacing is called **indentation**. Python uses indentation to show which lines of code belong together.
#
# For example:
#
# def myfunction(variable):
#
#     this information belongs to my function
#     return information from my function
#
# myfunction(variable)
#
#
# **Tip**: You can usually tell that the next line belongs to a block of code when the previous line ends with a colon (:). The next line must be indented.

# %% [markdown]
# # **What we learned so far:**
#
#
#
# *   **Variables store information** (for example, data entries) and should be named clearly to reflect what they represent.
# *   **Built-in functions** perform useful tasks and help you to manipulate your data.
# *   **External libraries** (for example, Numpy) provide additional functions that will help you to analyze your data
# *   If a function does not exist, you can create your own
# *   **You are more than welcomed to use functions you find online.** In your assignments, don’t hesitate to use functions or tools you discover outside of the tutorial—as long as you understand what they do. It doesn't have to be limited to what was shown in class.

# %% [markdown]
# # **Looking Ahead: Conditionals**
#
# So now we know about variables, how to use libraries, and even how to build our own functions, which a solid foundation for your future assignments.
#
# But in neuroscience experiments, we often deal with large datasets, and things can get more complicated.
#
# For example:
#
# *   Compare multiple variables (e.g. sleep vs. wake time)
# *   Filter data based on conditions (e.g. only look at NREM sleep)
# *   Detect specific events (e.g. count a reward bout when a mouse licks sugar water)
#
# ![12134141.png](data:image/png;base64,...)

# %% [markdown]
# 🧠 **There are multiple types of conditionals you can use in Python!**
#
# To get familiar with conditionals, we’ll work with experimental data where researchers recorded the amount of time a mouse spent in different states: **NREM sleep (NR)**, **REM sleep (R)**, and **wakefulness (W)**. **NR** and **R** represent different stages of sleep, while **W** represents periods when the mouse was awake. We'll use conditionals to explore, compare, and make decisions based on this data.
#
# Mouse_Sleep_Wake_Amounts = [NR,NR,NR,R,R,R,W,W,W,NR,NR,NR,NR,NR,W,NR]

# %% [markdown]
# # **For Loops**
#
# For loops are useful for iterating (going through) a list of data, one item at a time—from start to end.
#
# They are commonly used to repeat a set of commands for each trial, each mouse, or each time point in a dataset.
#
# In this example, you will use a for loop to go through an array of sleep-wake states, examining each state one by one. (for now)

# %%
#defining array with data of mouse's sleep-wake states
Mouse_Sleep_Wake_Amounts = ["NR", "NR", "NR", "R", "R", "R", "W", "W", "W", "NR", "NR", "NR", "NR", "NR", "W", "NR"]

#creating a for-loop
for state in Mouse_Sleep_Wake_Amounts: #sleep_wake_state is temporally element in the list.
  print(state) #print sleep_wake_state

# %% [markdown]
# We printed each state so you can see visually see that the for loop goes through each value (in this case, each string) in the list one by one.
#
# **TIP:** This print() in the list can also be helpful for checking if your code works correctly later on

# %%
#defining array with data of mouse's sleep-wake states
Mouse_Sleep_Wake_Amounts = ["NR", "NR", "NR", "R", "R", "R", "W", "W", "W", "NR", "NR", "NR", "NR", "NR", "W", "NR"]

#creating a for-loop
#sleep is temporally element in the list.
for state in Mouse_Sleep_Wake_Amounts:
    print(state) #print sleep_wake_state

# %% [markdown]
# ## **Comprehension question:** What does this error mean? Explain

# %% [markdown]
# # **IF Statements:**
#
# You can see that simply going through the list with a loop is not that helpful on its own. Yes, it goes through each state one by one—but what if you only want to isolate and work with **NREM (NR) sleep** values? This is where conditionals come in. By combining a loop with an if statement, we can tell Python to only do something when a specific condition is met—like when the state is **"NR"**.
#
# ![1131424.png](data:image/png;base64,...)

# %%
Mouse_Sleep_Wake_Amounts = ["NR", "NR", "NR", "R", "R", "R", "W", "W", "W", "NR", "NR", "NR", "NR", "NR", "W", "NR"]

#creating a for-loop
for sleep_wake_state in Mouse_Sleep_Wake_Amounts: #sleep_wake_state is temporally element in the list.
  if .. == "NR": #check if the temporally element meet a condition
    print(sleep_wake_state)

# %% [markdown]
# # **⚠️ Notice:**
#
# We used **==** inside the conditional statement. If you try to use a single **=** instead, Python will give you an error.
#
# That’s because:
#
# A **single =** is used to assign a value to a variable.
#
# A **double ==** is used to check whether two values are equal.
#
# So when you're writing an if statement to compare something—like checking if the current state is "NR"—you need to use "==", **not** "=".

# %%
Mouse_Sleep_Wake_Amounts = ["NR", "NR", "NR", "R", "R", "R", "W", "W", "W", "NR", "NR", "NR", "NR", "NR", "W", "NR"]

#creating a for-loop
for sleep_wake_state in Mouse_Sleep_Wake_Amounts: #sleep_wake_state is temporally element in the list.
  if sleep_wake_state = "NR": #check if the temporally element meet a condition
    print(sleep_wake_state)

# %% [markdown]
# ## *SyntaxError*
#
# The most common error in Python! In simple words, it means that you are violating the grammatcal rules of the language

# %% [markdown]
# # **Multiple Conditions with elif and else**
#
# Sometimes you want to check for more than one condition. For example, if you want to count how many times each sleep-wake state appears in your data set, you will need sort your data by state.
#
# To do this, you can use **elif statements, which let you check additional conditions after the first if.**
#
# To summarize:
#
#
#
# *   **if** checks the first condition
# *   **elif** checks other possibilities
# *   **else** (optional) runs if none of the above are true
#
# This helps your code make decisions based on multiple conditions, one after the other.

# %%
Mouse_Sleep_Wake_Amounts = ["NR", "NR", "NR", "R", "R", "R", "W", "W", "W", "NR", "NR", "NR", "NR", "NR", "W", "NR"]
wake_counter = 0
NREM_counter = 0
REM_counter = 0

#creating a for-loop
for sleep_wake_state in Mouse_Sleep_Wake_Amounts: #sleep_wake_state is temporally element in the list.
  if sleep_wake_state == "..": #check if the temporally element meet a condition
    .. = .. + 1 #add it to the counter
  elif sleep_wake_state == "..": #check if the temporally element meet a condition
    .. = .. + 1 #add it to the counter
  elif sleep_wake_state == "..": #check if the temporally element meet a condition
    .. = .. + 1 #add it to the counter

print(wake_counter)
print(NREM_counter)
print(REM_counter)

# %% [markdown]
# Sometimes, you would want to iterate through data and count it only **if it does not equal a certain value.** You can simply use **!=** to do that.
#
# The **!=** operator means "not equal to" and is useful when you want to exclude specific values during your analysis.

# %% [markdown]
# # **💪 Comprehension Question: Filtering and Categorizing Muscle Activity**
#
# You are analyzing muscle activity data collected from a mouse. The dataset includes values recorded during both sleep and wakefulness. **You are only interested in analyzing the muscle activity during wakefulness**, so you decide to:
#
# Filter out all values **below or equal to 1**, since mice tend to have very little
#
# 1.   Filter out all values **below or equal to 1**, since mice tend to have very little muscle activity during sleep.
# 2.   Store the remaining values in a new array called wakefulness_array.
#
#
# You then want to divide the **wakefulness data into two categories:**
#
#
# *   **Quiet wakefulness:** values less than or equal to 5
# *   **Active wakefulness:** values greater than 5
#
# Finally, you want to calculate how many values fall into each category.

# %%
mouse_muscle_activity = [1, 10, 4, 6, 1, 0, 55, 0.5, 3, 17]

# %% [markdown]
# # **What we have learned so far**
#
# *   For loops allow you to go through each item in a dataset and perform actions on them one at a time.
# *   If statements let you check whether a condition is true (or false) and run specific code based on that.
# *   Elif and else statements let you check additional conditions or provide a default action when none of the conditions are true.
# *   For and if together help you filter, count, and analyze your datasets efficiently!

# %% [markdown]
# # **Helpful Websites:**
#
# Free online course in Python that is avaliable for University of Toronto Students: https://www.datacamp.com/courses/intro-to-python-for-data-science
#
# Practice Python (Beginner-friendly exercises): https://www.practicepython.org/
#
# Practice Projects: https://github.com/karan/Projects-Solutions
#
#
# Python Language Glossary: https://www.w3schools.com/python/python_ref_functions.asp
